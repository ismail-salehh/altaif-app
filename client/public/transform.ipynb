# %%
import os
from PIL import Image

# %%
# Folder containing your images
input_folder = "nonconverted images/x"       # Change to your folder name
output_folder = "converted2"   # Output folder name

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Target size
TARGET_SIZE = (600, 600)

# Supported formats
valid_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

for filename in os.listdir(input_folder):
    if filename.lower().endswith(valid_extensions):
        img_path = os.path.join(input_folder, filename)

        img = Image.open(img_path)

        # Resize only if either dimension is greater than 600
        if img.width > 600 or img.height > 600:
            img.thumbnail(TARGET_SIZE, Image.Resampling.LANCZOS)

        # Convert and save as .webp
        base_name = os.path.splitext(filename)[0]
        output_path = os.path.join(output_folder, f"{base_name}.webp")

        img.save(output_path, "PNG", quality=90)
        print(f"✅ Converted: {filename} → {output_path}")

print("\nAll images processed successfully!")
# Out:
# ✅ Converted: StoryLogo.png → .\StoryLogo.svg
#
# All images processed successfully!

# %%
sounds = []

for filename in os.listdir('sounds'):
    sounds.append(os.path.splitext(filename)[0])
print(sounds)
# Out:
# ['0', '1', '2', '3ormore', 'adoll', 'alone', 'ascooter', 'atruck', 'awe', 'beach', 'blue', 'boy', 'breathe', 'buildacastle', 'buildahouse', 'buildalone', 'buildasandcastle', 'buildastatue', 'buildwithfriends', 'buildwithparents', 'buysomethingforyourself', 'chooseagame', 'city', 'darkness', 'discovernewplanets', 'discoverthehiddencave', 'discovertheotherdirection', 'dontbuysomethingforyourself', 'exciting', 'fear', 'feelhappy', 'feelneutral', 'feelsad', 'getout', 'girl', 'gobacktoearth', 'golefttothemaincabin', 'golefttotheopenarea', 'goonafactorytour', 'goonalittlespaceship', 'goplaywithhimontheplayground', 'goright', 'gorighttothenarrowcave', 'goshopping', 'goswimming', 'gotothearcade', 'gotothefactory', 'gotothepark', 'gototheplayground', 'gotothetoystore', 'green', 'heights', 'hikedown', 'hiketothetop', 'howdoyoufeel', 'howmanysiblingsdoyouhave', 'jungle', 'lookatthelandscapes', 'lookatthewindow', 'loudnoises', 'makefriendsandwatchthesky', 'petthedog', 'playalone', 'playbeachball', 'playonslides', 'playontheswing', 'playwithfamily', 'playwithfriends', 'playwithotherkids', 'playwiththeballalone', 'putyourfeetontheshore', 'red', 'ridethearialleftdown', 'ridetheariallift', 'shoppingwithparents', 'sitandwatchthesky', 'space', 'spiders', 'surfwithfriends', 'swim', 'talktoparents', 'talktothecaptain', 'talktothecaptainsdaughter', 'talktothegirl', 'talktothekidacrossthepath', 'wanttodiscovertheotherdirection', 'wanttogetout', 'watchamovieacrossthestreet', 'watchthesky', 'welcomeareyouaboyoragirl', 'whatdoyoudoafterthat', 'whatdoyoudotogether', 'whatdoyoufeel', 'whatdoyousaytohim', 'whatdoyouwanttobuild', 'whatdoyouwanttodo', 'whatdoyouwanttodointhecity', 'whatdoyouwanttodonext', 'whatdoyouwanttodoonthebeach', 'whatdoyouwanttodoonthemountain', 'whathappened', 'whatisyourfavoritecolor', 'whatkindofswimming', 'whatscaresyoumore', 'wheredoyouwanttogo', 'whichdirectionyouwanttotake', 'whoareyouplaying', 'whoareyoutalkingabout', 'whodoyouwanttobuild', 'whodoyouwanttoplay', 'whodoyouwanttoswim', 'withafriend', 'withfriends', 'withwhom', 'yellow', 'youfindabigspiderhowdoyoufeel', 'youseetheblueskywhatdoyouwanttodo']
